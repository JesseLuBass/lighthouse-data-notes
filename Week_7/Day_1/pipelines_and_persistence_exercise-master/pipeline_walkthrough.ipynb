# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
data = load_boston()
X_train, X_test, y_train, y_test = train_test_split(data['data'], data['target'])

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler, QuantileTransformer
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge

# %%
from sklearn.pipeline import Pipeline
pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('reduce_dim', PCA()),
        ('regressor', Ridge())
        ])

# %%
pipe = pipe.fit(X_train, y_train)
print('Testing score: ', pipe.score(X_test, y_test))
# Out:
# Testing score:  0.7026304724066041

# %%
print(pipe.steps[1][1].explained_variance_)
# Out:
# [6.30074685 1.40955714 1.24152926 0.84943985 0.77449805 0.66777356
#  0.53977907 0.38985679 0.26674182 0.19041446 0.17720518 0.16281714
#  0.06403237]

# %%
import numpy as np
n_features_to_test = np.arange(1, 11)

# %%
alpha_to_test = 2.0**np.arange(-6, +6)

# %%
params = {'reduce_dim__n_components': n_features_to_test,\
              'regressor__alpha': alpha_to_test}

# %%
from sklearn.model_selection import GridSearchCV
gridsearch = GridSearchCV(pipe, params, verbose=1).fit(X_train, y_train)
print('Final score is: ', gridsearch.score(X_test, y_test))
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# Final score is:  0.6550616312672872

# %%
gridsearch.best_params_
# Out:
# {'reduce_dim__n_components': 5, 'regressor__alpha': 0.015625}

# %%
scalers_to_test = [StandardScaler(), RobustScaler(), QuantileTransformer()]

# %%
params = {'scaler': scalers_to_test,
        'reduce_dim__n_components': n_features_to_test,\
        'regressor__alpha': alpha_to_test}

# %%
params = [
        {'scaler': scalers_to_test,
         'reduce_dim': [PCA()],
         'reduce_dim__n_components': n_features_to_test,\
         'regressor__alpha': alpha_to_test},

        {'scaler': scalers_to_test,
         'reduce_dim': [SelectKBest(f_regression)],
         'reduce_dim__k': n_features_to_test,\
         'regressor__alpha': alpha_to_test}
        ]

# %%
gridsearch = GridSearchCV(pipe, params, verbose=1).fit(X_train, y_train)
print('Final score is: ', gridsearch.score(X_test, y_test))
# Out:
# Fitting 5 folds for each of 720 candidates, totalling 3600 fits
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
# ...
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# Final score is:  0.677348293232366
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (303). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (304). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "

# %%
gridsearch.best_params_
# Out:
# {'reduce_dim': PCA(n_components=10),
#  'reduce_dim__n_components': 10,
#  'regressor__alpha': 4.0,
#  'scaler': RobustScaler()}

# %%
gridsearch.score(X_test, y_test)
# Out:
# 0.677348293232366

# %%
# IMPORT PACKAGES
from sklearn.svm import SVC
from sklearn.datasets import load_iris

from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion

from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest

# %%
iris = load_iris()

X, y = iris["data"], iris["target"]

# %%
# This dataset is way too high-dimensional. Better do PCA:
pca = PCA(n_components=2)

# Maybe some of the original features were good, too?
selection = SelectKBest(k=3)

# %%
# Build an transformer from PCA and Univariate selection:
combined_features = FeatureUnion([("pca", pca), ("univ_select", selection)])

# %%
# We will initialize the classifier
svm = SVC(kernel="linear")

# %%
# create our pipeline from FeatureUnion 
pipeline = Pipeline([("features", combined_features), ("svm", svm)])

# set up our parameters grid
param_grid = {"features__pca__n_components": [1, 2, 3],
                  "features__univ_select__k": [1, 2, 3],
                  "svm__C":[0.1, 1, 10]}

# create a Grid Search object
grid_search = GridSearchCV(pipeline, param_grid, verbose=10, refit=True)    

# fit the model and tune parameters
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5; 1/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=0.1
# [CV 1/5; 1/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 2/5; 1/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=0.1
# [CV 2/5; 1/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 3/5; 1/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=0.1
# [CV 3/5; 1/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 4/5; 1/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=0.1
# [CV 4/5; 1/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 5/5; 1/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=0.1
# [CV 5/5; 1/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 1/5; 2/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=1
# [CV 1/5; 2/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 2/5; 2/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=1
# [CV 2/5; 2/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 3/5; 2/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=1
# [CV 3/5; 2/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 4/5; 2/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=1
# [CV 4/5; 2/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 5/5; 2/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=1
# [CV 5/5; 2/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 1/5; 3/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=10
# [CV 1/5; 3/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 2/5; 3/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=10
# [CV 2/5; 3/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 3/5; 3/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=10
# [CV 3/5; 3/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 4/5; 3/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=10
# [CV 4/5; 3/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 5/5; 3/27] START features__pca__n_components=1, features__univ_select__k=1, svm__C=10
# [CV 5/5; 3/27] END features__pca__n_components=1, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 1/5; 4/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=0.1
# [CV 1/5; 4/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 2/5; 4/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=0.1
# [CV 2/5; 4/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 3/5; 4/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=0.1
# [CV 3/5; 4/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 4/5; 4/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=0.1
# [CV 4/5; 4/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 5/5; 4/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=0.1
# [CV 5/5; 4/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 1/5; 5/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=1
# [CV 1/5; 5/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 2/5; 5/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=1
# [CV 2/5; 5/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 3/5; 5/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=1
# [CV 3/5; 5/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 4/5; 5/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=1
# [CV 4/5; 5/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 5/5; 5/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=1
# [CV 5/5; 5/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 1/5; 6/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=10
# [CV 1/5; 6/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 2/5; 6/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=10
# [CV 2/5; 6/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 3/5; 6/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=10
# [CV 3/5; 6/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 4/5; 6/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=10
# [CV 4/5; 6/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 5/5; 6/27] START features__pca__n_components=1, features__univ_select__k=2, svm__C=10
# [CV 5/5; 6/27] END features__pca__n_components=1, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 1/5; 7/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=0.1
# [CV 1/5; 7/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 2/5; 7/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=0.1
# [CV 2/5; 7/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 3/5; 7/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=0.1
# [CV 3/5; 7/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 4/5; 7/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=0.1
# [CV 4/5; 7/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 5/5; 7/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=0.1
# [CV 5/5; 7/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 1/5; 8/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=1
# [CV 1/5; 8/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 2/5; 8/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=1
# [CV 2/5; 8/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 3/5; 8/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=1
# [CV 3/5; 8/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 4/5; 8/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=1
# [CV 4/5; 8/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 5/5; 8/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=1
# [CV 5/5; 8/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 1/5; 9/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=10
# [CV 1/5; 9/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 2/5; 9/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=10
# [CV 2/5; 9/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 3/5; 9/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=10
# [CV 3/5; 9/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 4/5; 9/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=10
# [CV 4/5; 9/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 5/5; 9/27] START features__pca__n_components=1, features__univ_select__k=3, svm__C=10
# [CV 5/5; 9/27] END features__pca__n_components=1, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 1/5; 10/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=0.1
# [CV 1/5; 10/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 2/5; 10/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=0.1
# [CV 2/5; 10/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 3/5; 10/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=0.1
# [CV 3/5; 10/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 4/5; 10/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=0.1
# [CV 4/5; 10/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 5/5; 10/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=0.1
# [CV 5/5; 10/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 1/5; 11/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=1
# [CV 1/5; 11/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 2/5; 11/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=1
# [CV 2/5; 11/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 3/5; 11/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=1
# [CV 3/5; 11/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 4/5; 11/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=1
# [CV 4/5; 11/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 5/5; 11/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=1
# [CV 5/5; 11/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 1/5; 12/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=10
# [CV 1/5; 12/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 2/5; 12/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=10
# [CV 2/5; 12/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 3/5; 12/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=10
# [CV 3/5; 12/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 4/5; 12/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=10
# [CV 4/5; 12/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 5/5; 12/27] START features__pca__n_components=2, features__univ_select__k=1, svm__C=10
# [CV 5/5; 12/27] END features__pca__n_components=2, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 1/5; 13/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=0.1
# [CV 1/5; 13/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 2/5; 13/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=0.1
# [CV 2/5; 13/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 3/5; 13/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=0.1
# [CV 3/5; 13/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 4/5; 13/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=0.1
# [CV 4/5; 13/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 5/5; 13/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=0.1
# [CV 5/5; 13/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 1/5; 14/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=1
# [CV 1/5; 14/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 2/5; 14/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=1
# [CV 2/5; 14/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 3/5; 14/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=1
# [CV 3/5; 14/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 4/5; 14/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=1
# [CV 4/5; 14/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 5/5; 14/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=1
# [CV 5/5; 14/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 1/5; 15/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=10
# [CV 1/5; 15/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 2/5; 15/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=10
# [CV 2/5; 15/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 3/5; 15/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=10
# [CV 3/5; 15/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 4/5; 15/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=10
# [CV 4/5; 15/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 5/5; 15/27] START features__pca__n_components=2, features__univ_select__k=2, svm__C=10
# [CV 5/5; 15/27] END features__pca__n_components=2, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 1/5; 16/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=0.1
# [CV 1/5; 16/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 2/5; 16/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=0.1
# [CV 2/5; 16/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 3/5; 16/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=0.1
# [CV 3/5; 16/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 4/5; 16/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=0.1
# [CV 4/5; 16/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 5/5; 16/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=0.1
# [CV 5/5; 16/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 1/5; 17/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=1
# [CV 1/5; 17/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 2/5; 17/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=1
# [CV 2/5; 17/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 3/5; 17/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=1
# [CV 3/5; 17/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 4/5; 17/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=1
# [CV 4/5; 17/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 5/5; 17/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=1
# [CV 5/5; 17/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 1/5; 18/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=10
# [CV 1/5; 18/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 2/5; 18/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=10
# [CV 2/5; 18/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 3/5; 18/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=10
# [CV 3/5; 18/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 4/5; 18/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=10
# [CV 4/5; 18/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 5/5; 18/27] START features__pca__n_components=2, features__univ_select__k=3, svm__C=10
# [CV 5/5; 18/27] END features__pca__n_components=2, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 1/5; 19/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=0.1
# [CV 1/5; 19/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 2/5; 19/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=0.1
# [CV 2/5; 19/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 3/5; 19/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=0.1
# [CV 3/5; 19/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 4/5; 19/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=0.1
# [CV 4/5; 19/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 5/5; 19/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=0.1
# [CV 5/5; 19/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=0.1; total time=   0.0s
# [CV 1/5; 20/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=1
# [CV 1/5; 20/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 2/5; 20/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=1
# [CV 2/5; 20/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 3/5; 20/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=1
# [CV 3/5; 20/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 4/5; 20/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=1
# [CV 4/5; 20/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 5/5; 20/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=1
# [CV 5/5; 20/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=1; total time=   0.0s
# [CV 1/5; 21/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=10
# [CV 1/5; 21/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 2/5; 21/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=10
# [CV 2/5; 21/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 3/5; 21/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=10
# [CV 3/5; 21/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 4/5; 21/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=10
# [CV 4/5; 21/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 5/5; 21/27] START features__pca__n_components=3, features__univ_select__k=1, svm__C=10
# [CV 5/5; 21/27] END features__pca__n_components=3, features__univ_select__k=1, svm__C=10; total time=   0.0s
# [CV 1/5; 22/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=0.1
# [CV 1/5; 22/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 2/5; 22/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=0.1
# [CV 2/5; 22/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 3/5; 22/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=0.1
# [CV 3/5; 22/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 4/5; 22/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=0.1
# [CV 4/5; 22/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 5/5; 22/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=0.1
# [CV 5/5; 22/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=0.1; total time=   0.0s
# [CV 1/5; 23/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=1
# [CV 1/5; 23/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 2/5; 23/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=1
# [CV 2/5; 23/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 3/5; 23/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=1
# [CV 3/5; 23/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 4/5; 23/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=1
# [CV 4/5; 23/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 5/5; 23/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=1
# [CV 5/5; 23/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=1; total time=   0.0s
# [CV 1/5; 24/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=10
# [CV 1/5; 24/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 2/5; 24/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=10
# [CV 2/5; 24/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 3/5; 24/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=10
# [CV 3/5; 24/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 4/5; 24/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=10
# [CV 4/5; 24/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 5/5; 24/27] START features__pca__n_components=3, features__univ_select__k=2, svm__C=10
# [CV 5/5; 24/27] END features__pca__n_components=3, features__univ_select__k=2, svm__C=10; total time=   0.0s
# [CV 1/5; 25/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=0.1
# [CV 1/5; 25/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 2/5; 25/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=0.1
# [CV 2/5; 25/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 3/5; 25/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=0.1
# [CV 3/5; 25/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 4/5; 25/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=0.1
# [CV 4/5; 25/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 5/5; 25/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=0.1
# [CV 5/5; 25/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=0.1; total time=   0.0s
# [CV 1/5; 26/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=1
# [CV 1/5; 26/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 2/5; 26/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=1
# [CV 2/5; 26/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 3/5; 26/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=1
# [CV 3/5; 26/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 4/5; 26/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=1
# [CV 4/5; 26/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 5/5; 26/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=1
# [CV 5/5; 26/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=1; total time=   0.0s
# [CV 1/5; 27/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=10
# [CV 1/5; 27/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 2/5; 27/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=10
# [CV 2/5; 27/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 3/5; 27/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=10
# [CV 3/5; 27/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 4/5; 27/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=10
# [CV 4/5; 27/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=10; total time=   0.0s
# [CV 5/5; 27/27] START features__pca__n_components=3, features__univ_select__k=3, svm__C=10
# [CV 5/5; 27/27] END features__pca__n_components=3, features__univ_select__k=3, svm__C=10; total time=   0.0s
# GridSearchCV(estimator=Pipeline(steps=[('features',
#                                         FeatureUnion(transformer_list=[('pca',
#                                                                         PCA(n_components=2)),
#                                                                        ('univ_select',
#                                                                         SelectKBest(k=3))])),
#                                        ('svm', SVC(kernel='linear'))]),
#              param_grid={'features__pca__n_components': [1, 2, 3],
#                          'features__univ_select__k': [1, 2, 3],
#                          'svm__C': [0.1, 1, 10]},
#              verbose=10)
