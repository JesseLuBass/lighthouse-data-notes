# %%
import pandas as pd

# %%
my_dict = { 'name' : ["a", "b", "c", "d", "e","f", "g"],
                   'age' : [20,27, 35, 55, 18, 21, 35],
                   'designation': ["VP", "CEO", "CFO", "VP", "VP", "CEO", "MD"]}

# %%
df = pd.DataFrame(my_dict)

# %%
df
# Out:
#   name  age designation
# 0    a   20          VP
# 1    b   27         CEO
# 2    c   35         CFO
# 3    d   55          VP
# 4    e   18          VP
# 5    f   21         CEO
# 6    g   35          MD

# %%
df.to_csv('csv_example')

# %%
df_csv = pd.read_csv('csv_example')

# %%
df_csv
# Out:
#    Unnamed: 0 name  age designation
# 0           0    a   20          VP
# 1           1    b   27         CEO
# 2           2    c   35         CFO
# 3           3    d   55          VP
# 4           4    e   18          VP
# 5           5    f   21         CEO
# 6           6    g   35          MD

# %%
df.to_csv('csv_example', index=False)

# %%
df_csv = pd.read_csv('csv_example')

# %%
df_csv
# Out:
#   name  age designation
# 0    a   20          VP
# 1    b   27         CEO
# 2    c   35         CFO
# 3    d   55          VP
# 4    e   18          VP
# 5    f   21         CEO
# 6    g   35          MD

# %%
df_csv = pd.read_csv('csv_example', header = [0,1,2])

# %%
df_csv
# Out:
#   name age designation
#      a  20          VP
#      b  27         CEO
# 0    c  35         CFO
# 1    d  55          VP
# 2    e  18          VP
# 3    f  21         CEO
# 4    g  35          MD

# %%
df_csv = pd.read_csv('csv_example', header = 5)

# %%
df_csv
# Out:
#    e  18   VP
# 0  f  21  CEO
# 1  g  35   MD

# %%
df_csv = pd.read_csv('csv_example', header = [1,2,5])

# %%
df_csv
# Out:
#    a  20   VP
#    b  27  CEO
#    e  18   VP
# 0  f  21  CEO
# 1  g  35   MD

# %%
df_csv = pd.read_csv('csv_example', names= ['a','b','c'])

# %%
df_csv
# Out:
#       a    b            c
# 0  name  age  designation
# 1     a   20           VP
# 2     b   27          CEO
# 3     c   35          CFO
# 4     d   55           VP
# 5     e   18           VP
# 6     f   21          CEO
# 7     g   35           MD

# %%
df_csv = pd.read_csv('csv_example', names = ['a','b','c'], header = 1)

# %%
df_csv
# Out:
#    a   b    c
# 0  b  27  CEO
# 1  c  35  CFO
# 2  d  55   VP
# 3  e  18   VP
# 4  f  21  CEO
# 5  g  35   MD

# %%
df.to_csv('csv_example', index=False, header = False)

# %%
df_csv = pd.read_csv('csv_example', names = ['NAME', 'AGE','DESTINATION'])

# %%
df_csv
# Out:
#   NAME  AGE DESTINATION
# 0    a   20          VP
# 1    b   27         CEO
# 2    c   35         CFO
# 3    d   55          VP
# 4    e   18          VP
# 5    f   21         CEO
# 6    g   35          MD

# %%
df.to_csv('csv_example', index=False, sep=':')

# %%
df_csv = pd.read_csv('csv_example', sep=':')

# %%
df_csv
# Out:
#   name  age designation
# 0    a   20          VP
# 1    b   27         CEO
# 2    c   35         CFO
# 3    d   55          VP
# 4    e   18          VP
# 5    f   21         CEO
# 6    g   35          MD

# %%
df_csv.set_index('name')
# Out:
#       age designation
# name
# a      20          VP
# b      27         CEO
# c      35         CFO
# d      55          VP
# e      18          VP
# f      21         CEO
# g      35          MD

# %%
df_csv = pd.read_csv('csv_example', sep = ':', index_col = 1)

# %%
df_csv
# Out:
#     name designation
# age
# 20     a          VP
# 27     b         CEO
# 35     c         CFO
# 55     d          VP
# 18     e          VP
# 21     f         CEO
# 35     g          MD

# %%
df_csv = pd.read_csv('csv_example', sep = ':', index_col = [0,1])

# %%
df_csv
# Out:
#          designation
# name age
# a    20           VP
# b    27          CEO
# c    35          CFO
# d    55           VP
# e    18           VP
# f    21          CEO
# g    35           MD

# %%
df_csv = pd.read_csv('csv_example', sep=':', nrows=3)

# %%
df_csv
# Out:
#   name  age designation
# 0    a   20          VP
# 1    b   27         CEO
# 2    c   35         CFO

# %%
df_csv = pd.read_csv('csv_example', skip_blank_lines = False, sep= ':')
